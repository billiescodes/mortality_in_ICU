# %% [markdown]
# Break up the work in milestones
#
# 1. First have a Patients Data Table ready
#     - uncover insights about the patients
#     -
#
# #### Notes:
# - WHERE clause goes at the end (even when selecting 2+ tables

# %%
# do I have to have postgressql (the app running? )
# do I have to keep postico running?

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
import time
import glob

# %%
ip_address = 'mimic-db-inst.cuk5g0jpkhib.us-west-2.rds.amazonaws.com:5432'

# %%
cnx = create_engine('postgresql://mimic:thisismetis@'+
                     ip_address +'/MIMIC_ICU')

# %%
pd.read_sql_query('''SELECT * from PATIENTS limit 5''',cnx)
# Out:
#    row_id  subject_id gender        dob                  dod dod_hosp  \
# 0     612         646      M 2128-01-05                 None     None
# 1     613         647      M 2106-03-24                 None     None
# 2     614         648      M 2139-07-13                 None     None
# 3     615         649      M 2177-06-23                 None     None
# 4     616         650      M 2051-04-15  2111-12-28 00:00:00     None
#
#                dod_ssn  expire_flag
# 0                 None            0
# 1                 None            0
# 2                 None            0
# 3                 None            0
# 4  2111-12-28 00:00:00            1

# %%
pd.read_sql_query(""" SELECT * from PATIENTS limit 5""", cnx)
# Out:
#    row_id  subject_id gender        dob                  dod dod_hosp  \
# 0     612         646      M 2128-01-05                 None     None
# 1     613         647      M 2106-03-24                 None     None
# 2     614         648      M 2139-07-13                 None     None
# 3     615         649      M 2177-06-23                 None     None
# 4     616         650      M 2051-04-15  2111-12-28 00:00:00     None
#
#                dod_ssn  expire_flag
# 0                 None            0
# 1                 None            0
# 2                 None            0
# 3                 None            0
# 4  2111-12-28 00:00:00            1

# %%
#'postgresql://dbadmin:thisismimic@'+ ip_address +'/MIMIC_ICU'

# %% [markdown]
# # 1. Start with Patients
# - DOB
# - ID
# - Expire Flag will whether they died in ICU
# - Patients contians exactly: r 38,645 adults and 7,875 neonates = 46520 entries

# %%
pd.read_sql_query(""" SELECT count(expire_flag) 
                from PATIENTS
                WHERE expire_flag = 1""", cnx)
# Out:
#    count
# 0  15759

# %%
pd.read_sql_query(""" SELECT count(expire_flag)  
                        from PATIENTS
                            WHERE expire_flag =0""", cnx)
# Out:
#    count
# 0  30761

# %% [markdown]
# TWICE AS MANY PEOPLE SURVIVE AS THE PEOPLE WHO DIE, SO LET'S SEE WHO THEY ARE!

# %%
pd.read_sql_query(""" SELECT * from PATIENTS limit 3""", cnx)
# Out:
#    row_id  subject_id gender        dob   dod dod_hosp dod_ssn  expire_flag
# 0     612         646      M 2128-01-05  None     None    None            0
# 1     613         647      M 2106-03-24  None     None    None            0
# 2     614         648      M 2139-07-13  None     None    None            0

# %%
# to find the age, link Patients (dob) on subject_id, and Admissions on subject_id 
pd.read_sql_query(""" SELECT * from ADMISSIONS limit 3""", cnx)
# Out:
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0      90          87   190659 2191-02-25 20:30:00 2191-04-25 15:18:00
# 1      91          88   123010 2111-08-29 03:03:00 2111-09-03 14:24:00
# 2      92          89   188646 2185-06-17 05:22:00 2185-06-21 11:15:00
#
#   deathtime admission_type         admission_location   discharge_location  \
# 0      None        NEWBORN  PHYS REFERRAL/NORMAL DELI  SHORT TERM HOSPITAL
# 1      None      EMERGENCY       EMERGENCY ROOM ADMIT                 HOME
# 2      None        NEWBORN  PHYS REFERRAL/NORMAL DELI  SHORT TERM HOSPITAL
#
#   insurance language      religion marital_status               ethnicity  \
# 0   Private           UNOBTAINABLE                  UNKNOWN/NOT SPECIFIED
# 1   Private                                        BLACK/AFRICAN AMERICAN
# 2  Medicaid           UNOBTAINABLE                  UNKNOWN/NOT SPECIFIED
#
#             edregtime           edouttime  \
# 0                 NaT                 NaT
# 1 2111-08-29 01:44:00 2111-08-29 02:28:00
# 2                 NaT                 NaT
#
#                              diagnosis  hospital_expire_flag  \
# 0                              NEWBORN                     0
# 1  S/P MOTOR VEHICLE ACCIDENT-STABBING                     0
# 2                              NEWBORN                     0
#
#    has_ioevents_data  has_chartevents_data
# 0                  1                     1
# 1                  1                     1
# 2                  1                     1

# %% [markdown]
# Keep
# + subject_id
# + gender
# + dob
# + dod
# + expire flag

# %%
### ~~ Table 1 

admit = pd.read_sql_query(""" SELECT Patients.subject_id, Patients.gender, Patients.dob, Patients.dod, Patients.expire_flag, Admissions.*
                        FROM Patients LEFT JOIN Admissions
                        ON Patients.subject_id = Admissions.subject_id
                        ORDER BY admission_type DESC""",cnx)
# GROUP BY 1

# %%
admit.to_csv("admit_1.csv", index=None)

# %%
admit[:1]
# Out:
#    subject_id gender                 dob dod  expire_flag  row_id  subject_id  \
# 0          30      M 1872-10-14 00:00:00 NaT            0      29          30
#
#    hadm_id           admittime           dischtime         ...           \
# 0   104557 2172-10-14 14:17:00 2172-10-19 14:37:00         ...
#
#   language  religion marital_status              ethnicity edregtime  \
# 0           CATHOLIC        MARRIED  UNKNOWN/NOT SPECIFIED      None
#
#   edouttime             diagnosis hospital_expire_flag has_ioevents_data  \
# 0      None  UNSTABLE ANGINA\CATH                    0                 1
#
#   has_chartevents_data
# 0                    1
#
# [1 rows x 25 columns]

# %%
#admit.info()

# %% [markdown]
# # 2. diagnoses-icd
#  ** Find the most common icd9_codes for fatal cases ***
# 1. try selecting the table
# 1. select most common icd9 code

# %%
## Run Test way down lbelow
test.table_name[test.table_name.str.contains('icd', na=False)]
# Out:
# 96        diagnoses_icd
# 135     d_icd_diagnoses
# 139    d_icd_procedures
# 173      procedures_icd
# Name: table_name, dtype: object

# %%
### look at icd9 codes to get the diagnosis
### Table 2
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0     243          34   115799        8     E8790
# 1     244          34   144319        1     42789
# 2     245          34   144319        2     42822
# 3     246          34   144319        3      4263

# %%
# most common code
pd.read_sql_query(''' SELECT count(icd9_code) FROM diagnoses_icd ''',cnx)
# Out:
#     count
# 0  651047

# %% [markdown]
# ### Must connect Expire_flag =1 . value_count(icd9_) among ADMISSIONS, not patients
#
# + Which icd9_code is most common among mortality cases (expire_flag = 1) for Admissions?
#
# + select  subject_id/hadm_id on Admissions and patients where e_f = 1
# + ** THEN look into the icd9_codes **

# %%
###### ~~ TABLE 2: 2nd saved table


#### get the most common icd9_codes in JOIN admissions/Patients
# ## Takes a while, but this works: 719641 rows × 4 columns

icd9_expire1 = pd.read_sql_query(''' SELECT admissions.hadm_id, admissions.subject_id, patients.expire_flag, diagnoses_icd.icd9_code
                        From admissions 
                        LEFT JOIN Patients 
                            ON admissions.subject_id = patients.subject_id
                        LEFT JOIN diagnoses_icd 
                            ON diagnoses_icd.subject_id = admissions.subject_id
                        WHERE expire_flag = 1
                    ''', cnx)
icd9_expire1[:5]
# Out:
#    hadm_id  subject_id  expire_flag icd9_code
# 0   121205          91            1     20008
# 1   121205          91            1      2765
# 2   121205          91            1      5559
# 3   121205          91            1     99812
# 4   121205          91            1     51881

# %%
icd9_expire1.to_csv("icd9_expire1.csv", index=None)

# %%
icd9_expire0 = pd.read_sql_query(''' SELECT admissions.hadm_id, admissions.subject_id, patients.expire_flag, diagnoses_icd.icd9_code
                        From admissions 
                        LEFT JOIN Patients 
                            ON admissions.subject_id = patients.subject_id
                        LEFT JOIN diagnoses_icd 
                            ON diagnoses_icd.subject_id = admissions.subject_id
                        WHERE expire_flag = 0
                    ''', cnx)
icd9_expire0[:5]
# Out:
#    hadm_id  subject_id  expire_flag icd9_code
# 0   163353           2            0     V3001
# 1   163353           2            0      V053
# 2   163353           2            0      V290
# 3   185777           4            0       042
# 4   185777           4            0      1363

# %%
icd9_expire0.to_csv("icd9_expire0.csv", index=None)

# %% [markdown]
# ## Obtain dictionary for icd9 codes

# %%
###### ~~ TABLE 4:  saved table

## Procedures
sql = """ SELECT * 
            from d_icd_procedures           
"""

procedures = pd.read_sql(sql, cnx)

# %%
#procedures.to_csv("mimic_data/procedures.csv", index=None)

# %%
###### ~~ TABLE 5:  saved table

# Diagrnoses AND the definitionbs for the DIagnoses from {d_icd_diagnoses}
sql = """ SELECT * 
            from diagnoses_icd 
            LEFT JOIN d_icd_diagnoses
                ON diagnoses_icd.icd9_code = d_icd_diagnoses.icd9_code
"""

diagnoses = pd.read_sql(sql, cnx)

# %%
diagnoses[:3]
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code   row_id icd9_code  \
# 0     243          34   115799      8.0     E8790  13429.0     E8790
# 1     244          34   144319      1.0     42789   4471.0     42789
# 2     245          34   144319      2.0     42822   4477.0     42822
#
#                 short_title                                         long_title
# 0    Abn react-cardiac cath  Cardiac catheterization as the cause of abnorm...
# 1  Cardiac dysrhythmias NEC               Other specified cardiac dysrhythmias
# 2  Chr systolic hrt failure                     Chronic systolic heart failure

# %%
diagnoses[:3]
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0     243          34   115799      8.0     E8790
# 1     244          34   144319      1.0     42789
# 2     245          34   144319      2.0     42822

# %%
diagnoses.to_csv("mimic_data/diagnoses.csv", index=None)

# %% [markdown]
# # I think Labevents will have the necessary Labs I'm looking for
# Number of rows: 27,872,575
#
# SO it might be smarter, to find first either
#  + what patients I'm interested in
#  + or what itemid's I'm interested in
#
# ** ITEMID --
# Identifier for a single measurement type in the database. Each row associated with one ITEMID (e.g. 212) corresponds to an instantiation of the same measurement (e.g. heart rate). **

# %%
pd.read_sql_query(""" SELECT *  
                    from LABEVENTS limit 5
                            """, cnx)
# Out:
#    row_id  subject_id hadm_id  itemid           charttime value  valuenum  \
# 0     281           3    None   50820 2101-10-12 17:07:00  7.39      7.39
# 1     282           3    None   50800 2101-10-12 19:17:00   ART       NaN
# 2     283           3    None   50802 2101-10-12 19:17:00    -1     -1.00
# 3     284           3    None   50804 2101-10-12 19:17:00    22     22.00
# 4     285           3    None   50808 2101-10-12 19:17:00  0.93      0.93
#
#   valueuom      flag
# 0    units
# 1
# 2    mEq/L
# 3    mEq/L
# 4   mmol/L  abnormal

# %%
## information on just one subject? 
len(tmp)
# Out:
# 1716

# %%
# start = time.time()
# pd.read_sql_query(""" SELECT *  from labevents """, cnx)
# print("total time: ", time.time()-start)

# %%
test.table_name[test.table_name.str.contains('lab', na=False)]
# Out:
# 21             pg_available_extensions
# 22     pg_available_extension_versions
# 25                        pg_seclabels
# 116                        pg_seclabel
# 117                      pg_shseclabel
# 149                         d_labitems
# 153                          labevents
# Name: table_name, dtype: object

# %%
start = time.time()
lab = pd.read_sql_query(""" SELECT *  from labevents """, cnx)
print("total time: ", time.time()-start)
# Out:
# ('total time: ', 22.716622829437256)

# %% [markdown]
# ## D_LABITEMS
# Table purpose: Definition table for all laboratory measurements.
# Number of rows: 755

# %%
labs = ['aniongap_min', 'aniongap_max',
       'albumin_min', 'albumin_max', 'bicarbonate_min', 'bicarbonate_max',
       'bilirubin_min', 'bilirubin_max', 'creatinine_min', 'creatinine_max',
        'chloride_min', 'chloride_max', 
    'hematocrit_min', 'hematocrit_max', 'hemoglobin_min', 'hemoglobin_max',
        'lactate_min', 'lactate_max', 'platelet_min', 'platelet_max',
           'potassium_min', 'potassium_max', 'ptt_min', 'ptt_max', 'inr_min',
        'inr_max', 'pt_min', 'pt_max', 'sodium_min', 'sodium_max', 'bun_min',
        'bun_max', 'wbc_min', 'wbc_max','sysbp_max', 'sysbp_mean', 'diasbp_min', 'diasbp_max', 'diasbp_mean',
        'meanbp_min', 'meanbp_max', 'meanbp_mean', 'resprate_min',
        'resprate_max', 'resprate_mean', 'tempc_min', 'tempc_max', 'tempc_mean',
        'spo2_min', 'spo2_max', 'spo2_mean']

# %%
('Anion gap', 'Respiratory Rate (Total)')
#NBP non-invasive BP 

#A BUN test is done to see how well your kidneys are working. 
#If your kidneys are not able to remove urea from the blood normally, 
#your BUN level rises. Heart failure, dehydration, or a diet high in protein can also make your BUN level higher. Liver disease or damage can lower your BUN level.

# %%
# Anion gap,
placeholder= '?'
lab_exact = ( 'Respiratory Rate (Total)' ','.join(placeholder * len(l))

# %%
#('Anion gap', 'Respiratory Rate (Total)')
## d_items
sql = """ SELECT itemid, label
        from d_items
        where label IN ( 'Anion gap', 'albumin','bicarbonate','Total Bilirubin','Creatinine' ,'chloride','hematocrit',
        'Hemoglobin','CEREBRAL LACTATE','Platelets','Potassium','Sodium','BUN', 'NBP [Systolic]','NBP [Diastolic]', 
        'Temperature C (calc)', 'Respiratory Rate (Total)', 'SpO2')
        
         """
labs = pd.read_sql_query(sql, cnx)

# %%
sql = """ SELECT label
        from d_items
        where label='Respiratory Rate (Total)'
        
         """
pd.read_sql_query(sql, cnx)
# Out:
#    row_id  itemid                     label              abbreviation  \
# 0   13246  224690  Respiratory Rate (Total)  Respiratory Rate (Total)
#
#      dbsource      linksto     category  unitname param_type conceptid
# 0  metavision  chartevents  Respiratory  insp/min    Numeric      None

# %%
labs
# Out:
#     itemid                     label
# 0      455            NBP [Systolic]
# 1     1162                       BUN
# 2      646                      SpO2
# 3      677      Temperature C (calc)
# 4      814                Hemoglobin
# 5      828                 Platelets
# 6     3066                   albumin
# 7     2638          CEREBRAL LACTATE
# 8     1525                Creatinine
# 9     1535                 Potassium
# 10    1536                    Sodium
# 11    8441           NBP [Diastolic]
# 12   30006                 Platelets
# 13   41956                 Potassium
# 14   46362               bicarbonate
# 15  225170                 Platelets
# 16  227073                 Anion gap
# 17  220228                Hemoglobin
# 18  224690  Respiratory Rate (Total)
# 19  225690           Total Bilirubin
# 20  225624                       BUN
# 21  220615                Creatinine
# 22   45403                   albumin

# %%
labs.itemid.values
# Out:
# array([   455,   1162,    646,    677,    814,    828,   3066,   2638,
#          1525,   1535,   1536,   8441,  30006,  41956,  46362, 225170,
#        227073, 220228, 224690, 225690, 225624, 220615,  45403])

# %%
chart_tables = [u'chartevents', u'chartevents_1', u'chartevents_10',
 u'chartevents_11', u'chartevents_12', u'chartevents_13', u'chartevents_14',
 u'chartevents_2', u'chartevents_3', u'chartevents_4', u'chartevents_5', u'chartevents_6', u'chartevents_7',
 u'chartevents_8', u'chartevents_9']

# %%
# Can I select Chartevents for just one patient?

# %%
start = time.time()
sql = """ SELECT subject_id, hadm_id, itemid, mean(valuenum) as val_mean, 
            min(valuenum) as val_min, max(valuesnum) as val_max
        from chartevents_1
        group by hadm_id
        where itemid= 455
         """
pd.read_sql_query(sql, cnx)
#print("total time: ", time.time()-start)

# %%
start = time.time()
sql = """ SELECT subject_id, hadm_id, itemid, mean(valuenum) as val_mean, 
            min(valuenum) as val_min, max(valuesnum) as val_max
        from chartevents_1
        group by hadm_id
        where itemid IN (  455,   1162,    646,    677,    814,    828,   3066,   2638,
         1525,   1535,   1536,   8441,  30006,  41956,  46362, 225170,
       227073, 220228, 224690, 225690, 225624, 220615,  45403)
         """
pd.read_sql_query(sql, cnx)
#print("total time: ", time.time()-start)

# %%
start = time.time()
sql = """ SELECT itemid, count(distinct subject_id) as num_patients
        from chartevents_1
        group by itemid
         """
df = pd.read_sql_query(sql, cnx)
df.to_csv('chartevents_1.csv', index=None)
print("total time: ", time.time()-start)

# %%
df
# Out:
#       row_id  subject_id  hadm_id  icustay_id  itemid           charttime  \
# 0   72456633        7447   128477      227749     198 2136-02-08 10:00:00
# 1   72456937        7447   128477      227749      52 2136-02-08 22:00:00
# 2   72456938        7447   128477      227749     159 2136-02-08 22:00:00
# 3   72456939        7447   128477      227749     161 2136-02-08 22:00:00
# 4   72456947        7447   128477      227749      52 2136-02-08 23:00:00
# 5   72456948        7447   128477      227749     159 2136-02-08 23:00:00
# 6   72456949        7447   128477      227749     161 2136-02-08 23:00:00
# 7   72456957        7447   128477      227749      52 2136-02-09 00:00:00
# 8   72456958        7447   128477      227749      77 2136-02-09 00:00:00
# 9   72456959        7447   128477      227749     127 2136-02-09 00:00:00
# 10  72456960        7447   128477      227749     161 2136-02-09 00:00:00
# 11  72456981        7447   128477      227749      52 2136-02-09 01:00:00
# 12  72456982        7447   128477      227749     161 2136-02-09 01:00:00
# 13  72402277        7433   105279      225177      82 2137-05-07 19:45:00
# 14  72402278        7433   105279      225177      83 2137-05-07 19:45:00
# 15  72402279        7433   105279      225177      84 2137-05-07 19:45:00
# 16  72402280        7433   105279      225177      85 2137-05-07 19:45:00
# 17  72402281        7433   105279      225177      86 2137-05-07 19:45:00
# 18  72402282        7433   105279      225177      87 2137-05-07 19:45:00
# 19  72402283        7433   105279      225177      88 2137-05-07 19:45:00
# 20  72402284        7433   105279      225177     127 2137-05-07 19:45:00
# 21  72402285        7433   105279      225177     128 2137-05-07 19:45:00
# 22  72402286        7433   105279      225177     130 2137-05-07 19:45:00
# 23  72402287        7433   105279      225177     159 2137-05-07 19:45:00
# 24  72402288        7433   105279      225177     161 2137-05-07 19:45:00
# 25  72402289        7433   105279      225177     165 2137-05-07 19:45:00
# 26  72402290        7433   105279      225177     167 2137-05-07 19:45:00
# 27  72403296        7433   105279      225177      52 2137-05-08 10:00:00
# 28  72403297        7433   105279      225177     127 2137-05-08 10:00:00
# 29  72403298        7433   105279      225177     128 2137-05-08 10:00:00
# ..       ...         ...      ...         ...     ...                 ...
# 70  72448646        7445   107485      213856     168 2188-04-17 13:00:00
# 71  72448647        7445   107485      213856     169 2188-04-17 13:00:00
# 72  72448648        7445   107485      213856     170 2188-04-17 13:00:00
# 73  72448649        7445   107485      213856     171 2188-04-17 13:00:00
# 74  72448650        7445   107485      213856     172 2188-04-17 13:00:00
# 75  72448651        7445   107485      213856     184 2188-04-17 13:00:00
# 76  72448653        7445   107485      213856     198 2188-04-17 13:00:00
# 77  72448654        7445   107485      213856     202 2188-04-17 13:00:00
# 78  72455634        7447   128477      227749      52 2136-02-06 21:00:00
# 79  72455635        7447   128477      227749     113 2136-02-06 21:00:00
# 80  72455636        7447   128477      227749     161 2136-02-06 21:00:00
# 81  72455643        7447   128477      227749      31 2136-02-06 22:00:00
# 82  72455644        7447   128477      227749      32 2136-02-06 22:00:00
# 83  72455645        7447   128477      227749      52 2136-02-06 22:00:00
# 84  72455646        7447   128477      227749      54 2136-02-06 22:00:00
# 85  72455647        7447   128477      227749     113 2136-02-06 22:00:00
# 86  72455648        7447   128477      227749     127 2136-02-06 22:00:00
# 87  72455649        7447   128477      227749     130 2136-02-06 22:00:00
# 88  72455650        7447   128477      227749     161 2136-02-06 22:00:00
# 89  72455651        7447   128477      227749     184 2136-02-06 22:00:00
# 90  72455652        7447   128477      227749     197 2136-02-06 22:00:00
# 91  72455653        7447   128477      227749     198 2136-02-06 22:00:00
# 92  72456008        7447   128477      227749      52 2136-02-07 07:00:00
# 93  72456009        7447   128477      227749     113 2136-02-07 07:00:00
# 94  72456010        7447   128477      227749     159 2136-02-07 07:00:00
# 95  72456011        7447   128477      227749     161 2136-02-07 07:00:00
# 96  72456019        7447   128477      227749      39 2136-02-07 07:55:00
# 97  72456020        7447   128477      227749      40 2136-02-07 07:55:00
# 98  72457040        7447   128477      227749      52 2136-02-09 03:00:00
# 99  72457041        7447   128477      227749     161 2136-02-09 03:00:00
#
#              storetime   cgid             value  valuenum valueuom warning  \
# 0  2136-02-08 09:51:00  17701                14      14.0   points    None
# 1  2136-02-08 22:19:00  18234               102     102.0     mmHg    None
# 2  2136-02-08 22:19:00  18234              None       NaN             None
# 3  2136-02-08 22:19:00  18234              None       NaN             None
# 4  2136-02-08 23:14:00  18234                82      82.0     mmHg    None
# 5  2136-02-08 23:14:00  18234              None       NaN             None
# 6  2136-02-08 23:14:00  18234              None       NaN             None
# 7  2136-02-09 00:16:00  18234                83      83.0     mmHg    None
# 8  2136-02-09 02:21:00  18234          Restless       NaN             None
# 9  2136-02-09 02:21:00  18234  Circulation Adeq       NaN             None
# 10 2136-02-09 00:16:00  18234              None       NaN             None
# 11 2136-02-09 02:21:00  18234                88      88.0     mmHg    None
# 12 2136-02-09 02:21:00  18234              None       NaN             None
# 13 2137-05-07 20:07:00  18941           Bedfast       NaN             None
# 14 2137-05-07 20:07:00  18941    Potential Prob       NaN             None
# 15 2137-05-07 20:07:00  18941      Very Limited       NaN             None
# 16 2137-05-07 20:07:00  18941      Rarely Moist       NaN             None
# 17 2137-05-07 20:07:00  18941  Prob. Inadequate       NaN             None
# 18 2137-05-07 20:07:00  18941                14      14.0   number    None
# 19 2137-05-07 20:07:00  18941       Sl. Limited       NaN             None
# 20 2137-05-07 20:07:00  18941  Circulation Adeq       NaN             None
# 21 2137-05-07 19:47:00  18941         Full Code       NaN             None
# 22 2137-05-07 20:07:00  18941              None       NaN             None
# 23 2137-05-07 19:47:00  18941              None       NaN             None
# 24 2137-05-07 19:47:00  18941              None       NaN             None
# 25 2137-05-07 20:07:00  18941       Altered LOC       NaN             None
# 26 2137-05-07 20:07:00  18941           Patient       NaN             None
# 27 2137-05-08 10:26:00  15355                75      75.0     mmHg    None
# 28 2137-05-08 10:53:00  15355  Circulation Adeq       NaN             None
# 29 2137-05-08 10:26:00  15355         Full Code       NaN             None
# ..                 ...    ...               ...       ...      ...     ...
# 70 2188-04-17 13:29:00  15653       Explanation       NaN             None
# 71 2188-04-17 13:29:00  15653                No       NaN             None
# 72 2188-04-17 13:29:00  15653       Understands       NaN             None
# 73 2188-04-17 13:29:00  15653      Plan of Care       NaN             None
# 74 2188-04-17 13:29:00  15653          Activity       NaN             None
# 75 2188-04-17 13:29:00  15653   4 Spontaneously       4.0             None
# 76 2188-04-17 13:29:00  15653                 9       9.0   points    None
# 77 2188-04-17 13:29:00  15653              Done       NaN             None
# 78 2136-02-06 21:34:00  20780                79      79.0     mmHg    None
# 79 2136-02-06 21:34:00  20780                 6       6.0     mmHg    None
# 80 2136-02-06 21:34:00  20780              None       NaN             None
# 81 2136-02-06 22:14:00  20780           Bedrest       NaN             None
# 82 2136-02-06 22:14:00  20780    Tolerated Well       NaN             None
# 83 2136-02-06 22:14:00  20780                88      88.0     mmHg    None
# 84 2136-02-06 22:14:00  20780   2 Person Assist       NaN             None
# 85 2136-02-06 22:14:00  20780                 5       5.0     mmHg    None
# 86 2136-02-06 22:14:00  20780  Circulation Adeq       NaN             None
# 87 2136-02-06 22:14:00  20780     Other/Remarks       NaN             None
# 88 2136-02-06 22:14:00  20780              None       NaN             None
# 89 2136-02-06 22:14:00  20780   4 Spontaneously       4.0             None
# 90 2136-02-06 22:14:00  20780      Consistently       NaN             None
# 91 2136-02-06 22:14:00  20780                11      11.0   points    None
# 92 2136-02-07 07:40:00  17701                81      81.0     mmHg    None
# 93 2136-02-07 07:40:00  17701                 4       4.0     mmHg    None
# 94 2136-02-07 07:40:00  17701              None       NaN             None
# 95 2136-02-07 07:40:00  17701              None       NaN             None
# 96 2136-02-07 07:56:00  21355            7.5 mm       NaN             None
# 97 2136-02-07 07:56:00  21355      Endotracheal       NaN             None
# 98 2136-02-09 03:19:00  18234                91      91.0     mmHg    None
# 99 2136-02-09 03:19:00  18234              None       NaN             None
#
#    error resultstatus   stopped
# 0   None               NotStopd
# 1   None               NotStopd
# 2   None               NotStopd
# 3   None               NotStopd
# 4   None               NotStopd
# 5   None               NotStopd
# 6   None               NotStopd
# 7   None               NotStopd
# 8   None               NotStopd
# 9   None               NotStopd
# 10  None               NotStopd
# 11  None               NotStopd
# 12  None               NotStopd
# 13  None               NotStopd
# 14  None               NotStopd
# 15  None               NotStopd
# 16  None               NotStopd
# 17  None               NotStopd
# 18  None               NotStopd
# 19  None               NotStopd
# 20  None               NotStopd
# 21  None               NotStopd
# 22  None               NotStopd
# 23  None               NotStopd
# 24  None               NotStopd
# 25  None               NotStopd
# 26  None               NotStopd
# 27  None               NotStopd
# 28  None               NotStopd
# 29  None               NotStopd
# ..   ...          ...       ...
# 70  None               NotStopd
# 71  None               NotStopd
# 72  None               NotStopd
# 73  None               NotStopd
# 74  None               NotStopd
# 75  None               NotStopd
# 76  None               NotStopd
# 77  None               NotStopd
# 78  None               NotStopd
# 79  None               NotStopd
# 80  None               NotStopd
# 81  None               NotStopd
# 82  None               NotStopd
# 83  None               NotStopd
# 84  None               NotStopd
# 85  None               NotStopd
# 86  None               NotStopd
# 87  None               NotStopd
# 88  None               NotStopd
# 89  None               NotStopd
# 90  None               NotStopd
# 91  None               NotStopd
# 92  None               NotStopd
# 93  None               NotStopd
# 94  None               NotStopd
# 95  None               NotStopd
# 96  None               NotStopd
# 97  None               NotStopd
# 98  None               NotStopd
# 99  None               NotStopd
#
# [100 rows x 15 columns]

# %%
pd.read_sql_query(""" SELECT *  
                    from D_LABITEMS
                     """, cnx)
# Out:
#      row_id  itemid                            label             fluid  \
# 0       262   51062                  CHLORIDE, STOOL             STOOL
# 1       263   51063                OSMOLALITY, STOOL             STOOL
# 2       264   51064                 POTASSIUM, STOOL             STOOL
# 3       265   51065                    SODIUM, STOOL             STOOL
# 4       266   51066                    24 HR CALCIUM             URINE
# 5       267   51067                 24 HR CREATININE             URINE
# 6       268   51068                    24 HR PROTEIN             URINE
# 7       269   51069                   ALBUMIN, URINE             URINE
# 8       270   51070        ALBUMIN/CREATININE, URINE             URINE
# 9       271   51071        AMPHETAMINE SCREEN, URINE             URINE
# 10      272   51072                   AMYLASE, URINE             URINE
# 11      273   51073  AMYLASE/CREATININE RATIO, URINE             URINE
# 12      274   51074        BARBITURATE SCREEN, URINE             URINE
# 13      275   51075     BENZODIAZEPINE SCREEN, URINE             URINE
# 14      276   51076               BICARBONATE, URINE             URINE
# 15      277   51077                   CALCIUM, URINE             URINE
# 16      278   51078                  CHLORIDE, URINE             URINE
# 17      279   51079                   COCAINE, URINE             URINE
# 18      280   51080             CREATININE CLEARANCE             URINE
# 19      281   51081                CREATININE, SERUM             URINE
# 20      282   51082                CREATININE, URINE             URINE
# 21      283   51083                   ETHANOL, URINE             URINE
# 22      284   51084                   GLUCOSE, URINE             URINE
# 23      285   51085          HCG, URINE, QUALITATIVE             URINE
# 24      286   51086            IMMUNOFIXATION, URINE             URINE
# 25      287   51087       LENGTH OF URINE COLLECTION             URINE
# 26      288   51088                 MAGNESIUM, URINE             URINE
# 27      289   51089                        MARIJUANA             URINE
# 28      290   51090                 METHADONE, URINE             URINE
# 29      291   51091                 MYOGLOBIN, URINE             URINE
# ..      ...     ...                              ...               ...
# 725     710   51510            URINE CRYSTALS, OTHER             URINE
# 726     711   51511                 URINE FAT BODIES             URINE
# 727     712   51512                     URINE MUCOUS             URINE
# 728     713   51513              URINE SPECIMEN TYPE             URINE
# 729     714   51514                     UROBILINOGEN             URINE
# 730     715   51515                       WAXY CASTS             URINE
# 731     716   51516                              WBC             URINE
# 732     717   51517                        WBC CASTS             URINE
# 733     718   51518                       WBC CLUMPS             URINE
# 734     719   51519                            YEAST             URINE
# 735     720   51520                          ANTI-MC             BLOOD
# 736     721   51521                        ACID PHOS             BLOOD
# 737     722   51522                               PG  OTHER BODY FLUID
# 738     723   51523                          GR HOLD             URINE
# 739     724   51524                            FATTY             URINE
# 740     725   51525                           Billed             BLOOD
# 741     726   51526                         FRUCAMN+             BLOOD
# 742     727   51527                           MS-DIA             BLOOD
# 743     728   51528                        STDY HOLD             BLOOD
# 744     729   51529                              eAG             BLOOD
# 745     730   51530                           AF-AFP  OTHER BODY FLUID
# 746     731   51531                        STDYURINE             URINE
# 747     732   51532                          PLASMGN             BLOOD
# 748     733   51533                             WBCP             BLOOD
# 749     734   51534                           MYELOS       JOINT FLUID
# 750     735   51535                             CD55  OTHER BODY FLUID
# 751     736   51536                             CD59  OTHER BODY FLUID
# 752     737   51537                              TDT  OTHER BODY FLUID
# 753     738   51538                            [A1c]             BLOOD
# 754     739   51539                        TACROFK_2             BLOOD
#
#        category loinc_code
# 0     CHEMISTRY    15158-9
# 1     CHEMISTRY     2693-0
# 2     CHEMISTRY    15202-5
# 3     CHEMISTRY    15207-4
# 4     CHEMISTRY     6874-2
# 5     CHEMISTRY     2162-6
# 6     CHEMISTRY     2889-4
# 7     CHEMISTRY     1754-1
# 8     CHEMISTRY    14958-3
# 9     CHEMISTRY     3349-8
# 10    CHEMISTRY     1799-6
# 11    CHEMISTRY    34235-2
# 12    CHEMISTRY     3377-9
# 13    CHEMISTRY     3390-2
# 14    CHEMISTRY     1964-6
# 15    CHEMISTRY     2004-0
# 16    CHEMISTRY     2078-4
# 17    CHEMISTRY     3397-7
# 18    CHEMISTRY    33558-8
# 19    CHEMISTRY
# 20    CHEMISTRY     2161-8
# 21    CHEMISTRY     5644-0
# 22    CHEMISTRY     2350-7
# 23    CHEMISTRY     2106-3
# 24    CHEMISTRY    49276-9
# 25    CHEMISTRY    13362-9
# 26    CHEMISTRY     2598-1
# 27    CHEMISTRY     3427-2
# 28    CHEMISTRY     3773-9
# 29    CHEMISTRY     2640-1
# ..          ...        ...
# 725  HEMATOLOGY     5783-6
# 726  HEMATOLOGY     2272-3
# 727  HEMATOLOGY     8247-9
# 728  HEMATOLOGY    19159-3
# 729  HEMATOLOGY     5818-0
# 730  HEMATOLOGY     5819-8
# 731  HEMATOLOGY     5821-4
# 732  HEMATOLOGY     5820-6
# 733  HEMATOLOGY
# 734  HEMATOLOGY     5822-2
# 735   CHEMISTRY    32042-4
# 736   CHEMISTRY     1711-1
# 737   CHEMISTRY    48785-0
# 738   CHEMISTRY
# 739  HEMATOLOGY     5789-3
# 740   CHEMISTRY
# 741   CHEMISTRY
# 742   CHEMISTRY
# 743   CHEMISTRY
# 744   CHEMISTRY
# 745   CHEMISTRY
# 746   CHEMISTRY
# 747  HEMATOLOGY
# 748  HEMATOLOGY
# 749  HEMATOLOGY
# 750  HEMATOLOGY
# 751  HEMATOLOGY
# 752  HEMATOLOGY
# 753   CHEMISTRY     4548-4
# 754   CHEMISTRY
#
# [755 rows x 6 columns]

# %% [markdown]
# ### rejected queries

# %%
sql = """ SELECT *  
        from D_LABITEMS
        WHERE label = 'resprate'"""
pd.read_sql_query(sql, cnx)
# Out:
# Empty DataFrame
# Columns: [row_id, itemid, label, fluid, category, loinc_code]
# Index: []

# %%
sql = """ SELECT *  
        from D_LABITEMS
        WHERE label = '24 HR PROTEIN'"""
pd.read_sql_query(sql, cnx)
# Out:
#    row_id  itemid          label  fluid   category loinc_code
# 0     268   51068  24 HR PROTEIN  URINE  CHEMISTRY     2889-4

# %%
## Code correct, but RUNS OUT OF STORAGE

# ## WIthout Limit 100: how many rows are there?

# sql = """SELECT  patients.expire_flag, diagnoses_icd.subject_id, diagnoses_icd.hadm_id,
#                                 diagnoses_icd.icd9_code
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     WHERE expire_flag=1 """
                    
# pd.read_sql(sql, cnx)

# %%
# Code correct, but RUNS OUT OF STORAGE
# sql = """  With new AS (SELECT  patients.expire_flag, diagnoses_icd.subject_id, diagnoses_icd.hadm_id,
#                                 diagnoses_icd.icd9_code
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     WHERE expire_flag=1 )
#  SELECT icd9_code, count(*) as num_icd
#                     FROM new
#                     GROUP BY icd9_code 
#                     order by num_icd desc"""
                    
# pd.read_sql(sql, cnx)

# %%
# ## TABLE 3  interrupted takes too long
# pd.read_sql_query(''' With new( SELECT  patients.expire_flag, diagnoses_icd.subject_id, diagnoses_icd.hadm_id,
#                                 diagnoses_icd.icd9_code
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     WHERE expire_flag=1 LIMIT 100)
#                     SELECT icd9_code, count(*)
#                     FROM new
#                     GROUP BY icd9_code''',cnx)

# %%
## TABLE 3 Doens't work
# pd.read_sql_query(''' select icd9_code, count(*) from (SELECT  patients.expire_flag, diagnoses_icd.subject_id, diagnoses_icd.hadm_id,
#                                 diagnoses_icd.icd9_code
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     WHERE expire_flag=1)
#                     group by icd9_code
#                     ''',cnx)

# %%
# Takes too long
# total number of icd9_codes
# pd.read_sql_query('''LIMIT 10 
#                 SELECT COUNT(DISTINCT icd9_code)
#                     FROM diagnoses_icd
#                     ''',cnx)

# %%
## # RUNS OUT OF STORAGE (POSSIBLY INCORRECT)

# pd.read_sql_query('''SELECT COUNT(DISTINCT diagnoses_icd.icd9_code)
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     GROUP BY patients.expire_flag
#                     HAVING patients.expire_flag =1
#                     ''',cnx)

# %%
## # RUNS OUT OF STORAGE

## Table 4: like Table 3 but sort according to most common icd9_code
 # (psycopg2.OperationalError) could not write block 1709405 of temporary file: No space left on device

# pd.read_sql_query('''SELECT COUNT(DISTINCT diagnoses_icd.icd9_code)
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     WHERE patients.expire_flag =1
#                     ''',cnx)

# %%
## # RUNS OUT OF STORAGE


## Table 4: like Table 3 but sort according to most common icd9_code
 # (psycopg2.OperationalError) could not write block 1709405 of temporary file: No space left on device

# pd.read_sql_query(''' SELECT patients.expire_flag, 
#                             COUNT(DISTINCT diagnoses_icd.icd9_code)
#                     FROM patients 
#                     LEFT JOIN diagnoses_icd 
#                         ON diagnoses_icd.subject_id=diagnoses_icd.subject_id
#                     GROUP BY patients.expire_flag
#                     LIMIT 10''',cnx)

# GROUP BY patients.expire_flag
#                    ORDER BY patients.expire_flag, icd9   DESC

# %%
                       # LEFT JOIN diagnoses_icd.subject_id = patients.subject_id
                                ,diagnoses_icd.icd9_code

# %%
#### Don't need 
# pd.read_sql_query(''' SELECT admissions.hadm_id, admissions.subject_id, patients.expire_flag
#                         From admissions 
#                         LEFT JOIN Patients 
#                             ON admissions.subject_id = patients.subject_id
#                         WHERE expire_flag = 1 limit 2
#                     ''', cnx)
# Out:
#    hadm_id  subject_id  expire_flag
# 0   145834           3            1
# 1   150750           9            1

# %%
# get the subject ID's where expire_flag = 1 and 

# ### Which icd9_code is most common among mortality cases (expire_flag = 1)
# pd.read_sql_query(''' SELECT diagnoses_icd.icd9_code, g, admissions.subject_id
#                     FROM diagnoses_icd LEFT JOIN admissions
#                     ON Diagnoses.subject_id
#                     WHERE expire_flag = 1
#                     ORDER BY count(icd9_code) limit 10''',cnx)

# %% [markdown]
# # Table d_icd_diagnose
# + does the d_ stand for something?
# + diagnoses_icd
#         96        diagnoses_icd
#         135     d_icd_diagnoses
#         139    d_icd_procedures
#         173      procedures_icd
#         Name: table_name, dtype: obje

# %%
#pd.read_sql_query(""" SELECT * from d_icd_diagnoses """, cnx)
pd.read_sql_query(""" SELECT * from diagnoses_icd order by subject_id, hadm_id, seq_num limit 10 """, cnx)
# Out:
#    row_id  subject_id  hadm_id  seq_num icd9_code
# 0       1           2   163353        1     V3001
# 1       2           2   163353        2      V053
# 2       3           2   163353        3      V290
# 3       4           3   145834        1      0389
# 4       5           3   145834        2     78559
# 5       6           3   145834        3      5849
# 6       7           3   145834        4      4275
# 7       8           3   145834        5     41071
# 8       9           3   145834        6      4280
# 9      10           3   145834        7      6826

# %% [markdown]
# # Procedures Table to find what they were in for

# %%
pd.read_sql_query(""" SELECT * from d_icd_procedures""", cnx)

# %%
pd.read_sql_query(""" SELECT count(long_title) from d_icd_procedures""", cnx)

# %%
#d_icd_procedures table 
pd.read_sql_query(""" SELECT count( short_title) from d_icd_procedures""", cnx)

# %%
#cnx = create_engine("postgresql://localhost/postgres")

# %%
pd.read_sql_query('''SELECT count(ROW_ID) from PATIENTS''',cnx)

# %% [markdown]
# ## select all the tables? : test variable

# %%
tables= pd.read_sql_query('''SELECT * FROM information_schema.tables''',cnx)

# %%
tables.columns
# Out:
# Index([u'table_catalog', u'table_schema', u'table_name', u'table_type',
#        u'self_referencing_column_name', u'reference_generation',
#        u'user_defined_type_catalog', u'user_defined_type_schema',
#        u'user_defined_type_name', u'is_insertable_into', u'is_typed',
#        u'commit_action'],
#       dtype='object')

# %%
tables.head(2)
# Out:
#   table_catalog table_schema       table_name  table_type  \
# 0     MIMIC_ICU       public  w_chartevents_3  BASE TABLE
# 1     MIMIC_ICU       public  w_chartevents_4  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None

# %%
len(tables.table_name.unique())
# Out:
# 216

# %%
test = pd.read_sql_query('''SELECT table_name FROM information_schema.tables''',cnx)

# %%
# Series of all the available tables
test[:4]
#print(len(test))
# Out:
#         table_name
# 0  w_chartevents_3
# 1  w_chartevents_4
# 2          pg_type
# 3  w_chartevents_5

# %%
charts = test.table_name[test.table_name.str.contains('chartevents', na=False)]

# %%
charts
# Out:
# 0       w_chartevents_3
# 1       w_chartevents_4
# 3       w_chartevents_5
# 4       w_chartevents_6
# 5       w_chartevents_2
# 6      w_chartevents_13
# 7      w_chartevents_14
# 34        chartevents_1
# 35        chartevents_2
# 36        chartevents_3
# 37        chartevents_4
# 38        chartevents_5
# 39        chartevents_6
# 40        chartevents_7
# 60        chartevents_8
# 61        chartevents_9
# 62       chartevents_10
# 63          chartevents
# 64       chartevents_11
# 66       chartevents_12
# 68       chartevents_13
# 69       chartevents_14
# 186    w_chartevents_10
# 187    w_chartevents_11
# 188    w_chartevents_12
# 209     w_chartevents_7
# 210     w_chartevents_9
# 211     w_chartevents_8
# 212     w_chartevents_1
# 214       w_chartevents
# Name: table_name, dtype: object

# %%
test
icd = test.table_name[test.table_name.str.contains('icd', na=False)]

# %%
icd

# %% [markdown]
# # Chartevents
# Kind of a specialized table that tracks the charted events for patients
#
# + what is the difference b/w w_chartevents, and just chartevents?
# + same for extension _3, _4 etc

# %%
#pd.read_sql_query('''SELECT * from chartevents limit 2''',cnx)

# %%
#pd.read_sql_query('''SELECT count(DISTINCT subject_id) from chartevents limit10''', cnx)

# %%
# Can you select all the patients/how many different patients in chartevents

pd.read_sql_query('''SELECT count( subject_id) from chartevents''', cnx)

# %%
chart_events = test.table_name[test.table_name.str.contains('chartevents', na=False)]

# %%
pd.read_sql_query('''SELECT * from chartevents_1 limit 2''',cnx)

# %%
#chart_events
pd.read_sql_query('''SELECT subject_id from chartevents_1''',cnx)
